# %% [markdown]
# # Packages import

# %%
import requests
from flask import Flask
from bs4 import BeautifulSoup

# %% [markdown]
# ## News scraper

# %% [markdown]
# 1. Provide URL address of article webpage

# %%
article_code = "2026/06/cybersecurity-stars-awards-2026-winners.html"
url = f"https://thehackernews.com/{article_code}"

# %% [markdown]
# 2. Send the request to provided URL address

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# 3. If status code is OK, fetch article name

# %%
page_dom = BeautifulSoup(response.text, 'html.parser')
print(type(page_dom))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
product_name = page_dom.select_one("#app > div > h1 > a").get_text()
print(product_name)
# Out:
# Cybersecurity Stars Awards 2026: Winners Announced Across 95 Categories

# %% [markdown]
# 4. If status code is OK, fetch all opinions from requested webpage

# %% [markdown]
# 5. For all fetched opinions, parse them to extract relevant data

# %%
all_articles = []
for article in articles:
    single_article = {
        'title': article['#app > div > h1 > a']
    }

# %% [markdown]
# 6. Check if there is next page with opinions

# %% [markdown]
# 8. Save obtained opinions
